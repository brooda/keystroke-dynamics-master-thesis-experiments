# %%
from plot import plot

# %%
#file_names =["mobikey_dup", "mobikey_dup_xy", "mobikey_dup_xytoeplitz", \
#        "mobikey_accx", "mobikey_accy", "mobikey_accz", \
#        "mobikey_accxy","mobikey_accxz", "mobikey_accyz", "mobikey_accxyz"]

file_names =["mobile_accxy"]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_mobile_accxy
# {0.77 (0.35) & 0.77 (0.35) & 0.77 (0.35) & 0.76 (0.35) & 0.76 (0.35) & 0.75 (0.36) }
# {0.82 (0.35) & 0.82 (0.35) & 0.82 (0.35) & 0.82 (0.36) & 0.81 (0.36) & 0.81 (0.36) }
# {0.79 (0.36) & 0.79 (0.36) & 0.79 (0.36) & 0.79 (0.36) & 0.79 (0.37) & 0.79 (0.37) }
# {0.76 (0.37) & 0.77 (0.37) & 0.76 (0.37) & 0.75 (0.37) & 0.75 (0.37) & 0.74 (0.37) }
