# %%
from plot import plot

# %%
file_names =["swipe_accx_mean", "swipe_accx_rms", "swipe_accx_both",\
    "swipe_accy_mean", "swipe_accy_rms", "swipe_accy_both",\
    "swipe_accz_mean", "swipe_accz_rms", "swipe_accz_both",\
    "swipe_rotx_mean", "swipe_rotx_rms", "swipe_rotx_both",\
    "swipe_roty_mean", "swipe_roty_rms", "swipe_roty_both",\
    "swipe_rotz_mean", "swipe_rotz_rms", "swipe_rotz_both"\
]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_swipe_accx_mean
# {0.87 (0.22) & 0.89 (0.22) & 0.88 (0.22) & 0.86 (0.23) & 0.84 (0.25) & 0.82 (0.27) }
# {0.89 (0.22) & 0.90 (0.21) & 0.89 (0.21) & 0.88 (0.22) & 0.87 (0.23) & 0.85 (0.24) }
# {0.75 (0.39) & 0.75 (0.39) & 0.75 (0.39) & 0.74 (0.39) & 0.74 (0.39) & 0.74 (0.38) }
# {0.76 (0.35) & 0.77 (0.35) & 0.76 (0.35) & 0.76 (0.35) & 0.75 (0.35) & 0.74 (0.36) }
# v2_swipe_accx_rms
# {0.86 (0.24) & 0.87 (0.24) & 0.86 (0.24) & 0.85 (0.24) & 0.83 (0.25) & 0.82 (0.26) }
# {0.88 (0.23) & 0.89 (0.23) & 0.88 (0.23) & 0.88 (0.23) & 0.87 (0.23) & 0.86 (0.24) }
# {0.83 (0.29) & 0.83 (0.29) & 0.83 (0.29) & 0.82 (0.29) & 0.82 (0.29) & 0.81 (0.29) }
# {0.70 (0.35) & 0.70 (0.35) & 0.70 (0.35) & 0.70 (0.35) & 0.69 (0.35) & 0.69 (0.35) }
# v2_swipe_accx_both
# {nan (nan) & nan (nan) & nan (nan) & nan (nan) & nan (nan) & nan (nan) }
# {0.85 (0.26) & 0.85 (0.26) & 0.85 (0.26) & 0.85 (0.26) & 0.84 (0.26) & 0.84 (0.26) }
# {0.75 (0.35) & 0.76 (0.35) & 0.76 (0.35) & 0.75 (0.35) & 0.75 (0.35) & 0.74 (0.35) }
# {0.81 (0.31) & 0.82 (0.30) & 0.81 (0.30) & 0.80 (0.31) & 0.79 (0.32) & 0.77 (0.33) }
# v2_swipe_accy_mean
# {0.90 (0.21) & 0.92 (0.21) & 0.91 (0.21) & 0.89 (0.21) & 0.88 (0.22) & 0.86 (0.23) }
# {0.86 (0.28) & 0.87 (0.28) & 0.86 (0.27) & 0.84 (0.28) & 0.83 (0.29) & 0.81 (0.30) }
# {0.89 (0.24) & 0.90 (0.24) & 0.89 (0.24) & 0.88 (0.25) & 0.87 (0.26) & 0.86 (0.27) }
# {0.75 (0.34) & 0.76 (0.33) & 0.76 (0.34) & 0.74 (0.35) & 0.73 (0.36) & 0.71 (0.37) }
# v2_swipe_accy_rms
# {0.94 (0.11) & 0.97 (0.09) & 0.95 (0.10) & 0.93 (0.13) & 0.90 (0.16) & 0.88 (0.19) }
# {0.83 (0.29) & 0.85 (0.29) & 0.84 (0.29) & 0.83 (0.29) & 0.81 (0.30) & 0.79 (0.31) }
# {0.89 (0.23) & 0.90 (0.23) & 0.89 (0.23) & 0.88 (0.24) & 0.87 (0.25) & 0.86 (0.26) }
# {0.77 (0.31) & 0.79 (0.30) & 0.78 (0.31) & 0.76 (0.32) & 0.74 (0.33) & 0.72 (0.35) }
# v2_swipe_accy_both
# {0.94 (0.11) & 0.97 (0.09) & 0.95 (0.10) & 0.93 (0.13) & 0.90 (0.16) & 0.88 (0.19) }
# {0.84 (0.29) & 0.85 (0.29) & 0.85 (0.29) & 0.84 (0.29) & 0.83 (0.29) & 0.82 (0.29) }
# {0.91 (0.19) & 0.92 (0.18) & 0.92 (0.18) & 0.90 (0.20) & 0.89 (0.21) & 0.87 (0.23) }
# {0.73 (0.37) & 0.74 (0.37) & 0.74 (0.37) & 0.72 (0.38) & 0.71 (0.38) & 0.70 (0.39) }
# v2_swipe_accz_mean
# {0.89 (0.21) & 0.92 (0.21) & 0.90 (0.21) & 0.88 (0.21) & 0.85 (0.23) & 0.82 (0.25) }
# {0.90 (0.21) & 0.92 (0.21) & 0.91 (0.21) & 0.89 (0.22) & 0.87 (0.22) & 0.85 (0.24) }
# {0.86 (0.30) & 0.87 (0.29) & 0.86 (0.29) & 0.86 (0.30) & 0.85 (0.31) & 0.84 (0.31) }
# {0.75 (0.39) & 0.75 (0.39) & 0.75 (0.39) & 0.74 (0.39) & 0.74 (0.39) & 0.73 (0.39) }
# v2_swipe_accz_rms
# {0.86 (0.26) & 0.88 (0.26) & 0.87 (0.26) & 0.85 (0.26) & 0.83 (0.27) & 0.81 (0.29) }
# {0.87 (0.29) & 0.89 (0.29) & 0.88 (0.29) & 0.86 (0.29) & 0.84 (0.30) & 0.83 (0.31) }
# {0.87 (0.28) & 0.88 (0.28) & 0.87 (0.28) & 0.86 (0.28) & 0.85 (0.29) & 0.84 (0.30) }
# {0.73 (0.39) & 0.73 (0.39) & 0.73 (0.39) & 0.73 (0.39) & 0.72 (0.39) & 0.72 (0.39) }
# v2_swipe_accz_both
# {0.85 (0.27) & 0.87 (0.27) & 0.86 (0.27) & 0.84 (0.27) & 0.82 (0.28) & 0.80 (0.30) }
# {0.89 (0.24) & 0.91 (0.24) & 0.90 (0.24) & 0.88 (0.24) & 0.86 (0.25) & 0.84 (0.26) }
# {0.84 (0.29) & 0.85 (0.29) & 0.84 (0.29) & 0.83 (0.30) & 0.81 (0.31) & 0.80 (0.32) }
# {0.79 (0.36) & 0.80 (0.36) & 0.79 (0.36) & 0.79 (0.36) & 0.79 (0.37) & 0.79 (0.37) }
# v2_swipe_rotx_mean
# {0.72 (0.35) & 0.73 (0.35) & 0.72 (0.35) & 0.71 (0.34) & 0.70 (0.34) & 0.68 (0.34) }
# {0.57 (0.34) & 0.58 (0.34) & 0.58 (0.34) & 0.57 (0.34) & 0.56 (0.34) & 0.55 (0.34) }
# {0.69 (0.39) & 0.69 (0.39) & 0.69 (0.39) & 0.69 (0.39) & 0.68 (0.39) & 0.68 (0.39) }
# {0.74 (0.35) & 0.76 (0.36) & 0.75 (0.35) & 0.73 (0.35) & 0.70 (0.35) & 0.68 (0.36) }
# v2_swipe_rotx_rms
# {0.89 (0.18) & 0.90 (0.19) & 0.90 (0.18) & 0.88 (0.19) & 0.86 (0.19) & 0.84 (0.20) }
# {0.81 (0.29) & 0.82 (0.29) & 0.82 (0.29) & 0.81 (0.29) & 0.81 (0.29) & 0.80 (0.29) }
# {0.76 (0.29) & 0.77 (0.29) & 0.76 (0.29) & 0.75 (0.29) & 0.74 (0.29) & 0.73 (0.29) }
# {0.78 (0.32) & 0.79 (0.33) & 0.79 (0.33) & 0.78 (0.32) & 0.77 (0.32) & 0.76 (0.32) }
# v2_swipe_rotx_both
# {0.77 (0.35) & 0.79 (0.35) & 0.78 (0.35) & 0.76 (0.35) & 0.74 (0.34) & 0.73 (0.34) }
# {0.69 (0.32) & 0.69 (0.32) & 0.69 (0.32) & 0.68 (0.32) & 0.67 (0.33) & 0.66 (0.33) }
# {0.60 (0.38) & 0.61 (0.39) & 0.60 (0.38) & 0.59 (0.38) & 0.58 (0.38) & 0.57 (0.38) }
# {0.68 (0.37) & 0.70 (0.38) & 0.69 (0.37) & 0.67 (0.37) & 0.65 (0.37) & 0.63 (0.37) }
# v2_swipe_roty_mean
# {0.74 (0.36) & 0.76 (0.36) & 0.75 (0.36) & 0.73 (0.35) & 0.72 (0.35) & 0.70 (0.35) }
# {0.59 (0.39) & 0.59 (0.39) & 0.59 (0.39) & 0.58 (0.39) & 0.58 (0.39) & 0.58 (0.39) }
# {0.64 (0.38) & 0.64 (0.38) & 0.64 (0.38) & 0.63 (0.37) & 0.62 (0.37) & 0.62 (0.37) }
# {0.64 (0.43) & 0.65 (0.43) & 0.64 (0.43) & 0.63 (0.42) & 0.62 (0.42) & 0.60 (0.42) }
# v2_swipe_roty_rms
# {0.68 (0.35) & 0.69 (0.36) & 0.68 (0.36) & 0.68 (0.35) & 0.67 (0.35) & 0.66 (0.35) }
# {0.58 (0.38) & 0.60 (0.39) & 0.59 (0.38) & 0.57 (0.37) & 0.55 (0.37) & 0.54 (0.36) }
# {0.56 (0.38) & 0.57 (0.38) & 0.56 (0.38) & 0.55 (0.38) & 0.54 (0.38) & 0.52 (0.38) }
# {0.57 (0.42) & 0.58 (0.42) & 0.58 (0.42) & 0.57 (0.42) & 0.56 (0.42) & 0.55 (0.42) }
# v2_swipe_roty_both
# {0.74 (0.35) & 0.76 (0.35) & 0.75 (0.35) & 0.73 (0.35) & 0.72 (0.34) & 0.70 (0.34) }
# {0.58 (0.38) & 0.59 (0.38) & 0.59 (0.38) & 0.58 (0.37) & 0.57 (0.37) & 0.56 (0.36) }
# {0.54 (0.38) & 0.55 (0.38) & 0.54 (0.38) & 0.53 (0.37) & 0.52 (0.37) & 0.51 (0.37) }
# {0.61 (0.38) & 0.62 (0.39) & 0.61 (0.38) & 0.60 (0.38) & 0.59 (0.37) & 0.58 (0.37) }
# v2_swipe_rotz_mean
# {0.78 (0.28) & 0.80 (0.28) & 0.79 (0.28) & 0.77 (0.28) & 0.75 (0.29) & 0.73 (0.30) }
# {0.74 (0.31) & 0.75 (0.31) & 0.75 (0.31) & 0.74 (0.31) & 0.73 (0.31) & 0.73 (0.31) }
# {0.67 (0.39) & 0.67 (0.39) & 0.67 (0.39) & 0.67 (0.39) & 0.66 (0.39) & 0.66 (0.39) }
# {0.69 (0.38) & 0.70 (0.38) & 0.69 (0.38) & 0.69 (0.38) & 0.68 (0.38) & 0.68 (0.38) }
# v2_swipe_rotz_rms
# {0.82 (0.25) & 0.84 (0.26) & 0.83 (0.26) & 0.82 (0.25) & 0.80 (0.25) & 0.79 (0.25) }
# {0.82 (0.18) & 0.83 (0.17) & 0.82 (0.18) & 0.81 (0.18) & 0.80 (0.19) & 0.80 (0.20) }
# {0.82 (0.25) & 0.83 (0.25) & 0.83 (0.25) & 0.82 (0.25) & 0.80 (0.25) & 0.79 (0.25) }
# {0.75 (0.27) & 0.76 (0.28) & 0.75 (0.27) & 0.74 (0.27) & 0.73 (0.27) & 0.72 (0.27) }
# v2_swipe_rotz_both
# {0.68 (0.38) & 0.69 (0.39) & 0.68 (0.38) & 0.67 (0.37) & 0.65 (0.37) & 0.63 (0.36) }
# {0.70 (0.32) & 0.71 (0.31) & 0.70 (0.31) & 0.69 (0.32) & 0.68 (0.32) & 0.67 (0.32) }
# {0.64 (0.37) & 0.64 (0.37) & 0.64 (0.37) & 0.64 (0.37) & 0.63 (0.37) & 0.63 (0.37) }
# {0.67 (0.37) & 0.68 (0.37) & 0.67 (0.37) & 0.66 (0.36) & 0.65 (0.36) & 0.64 (0.36) }
