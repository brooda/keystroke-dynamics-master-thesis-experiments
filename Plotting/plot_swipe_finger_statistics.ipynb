# %%
from plot import plot

# %%
file_names =["swipe_stat_pos_mean", "swipe_stat_pos_rms", "swipe_stat_pos_both", \
    "swipe_stat_vel_mean", "swipe_stat_vel_rms", "swipe_stat_vel_both", \
    "swipe_stat_acc_mean", "swipe_stat_acc_rms", "swipe_stat_acc_both"]

file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    print()
# Out:
# v2_swipe_stat_pos_mean
# {0.61 (0.34) & 0.62 (0.35) & 0.61 (0.34) & 0.59 (0.34) & 0.58 (0.33) & 0.56 (0.33) }
# {0.62 (0.32) & 0.62 (0.33) & 0.62 (0.32) & 0.61 (0.32) & 0.61 (0.32) & 0.60 (0.32) }
# {0.43 (0.36) & 0.43 (0.37) & 0.43 (0.37) & 0.42 (0.36) & 0.42 (0.36) & 0.42 (0.36) }
# {0.57 (0.39) & 0.58 (0.40) & 0.57 (0.39) & 0.56 (0.39) & 0.55 (0.38) & 0.54 (0.37) }
# v2_swipe_stat_pos_rms
# {0.54 (0.32) & 0.56 (0.33) & 0.55 (0.32) & 0.53 (0.31) & 0.51 (0.30) & 0.50 (0.29) }
# {0.50 (0.28) & 0.51 (0.29) & 0.50 (0.29) & 0.50 (0.28) & 0.49 (0.28) & 0.48 (0.28) }
# {0.44 (0.34) & 0.44 (0.35) & 0.44 (0.34) & 0.43 (0.34) & 0.43 (0.34) & 0.42 (0.34) }
# {0.61 (0.38) & 0.62 (0.39) & 0.61 (0.39) & 0.60 (0.37) & 0.58 (0.36) & 0.57 (0.35) }
# v2_swipe_stat_pos_both
# {0.61 (0.32) & 0.63 (0.33) & 0.62 (0.32) & 0.59 (0.32) & 0.57 (0.32) & 0.55 (0.31) }
# {0.50 (0.31) & 0.51 (0.31) & 0.50 (0.31) & 0.49 (0.30) & 0.48 (0.30) & 0.47 (0.30) }
# {0.42 (0.33) & 0.42 (0.33) & 0.42 (0.33) & 0.41 (0.33) & 0.41 (0.33) & 0.40 (0.33) }
# {0.68 (0.34) & 0.71 (0.36) & 0.70 (0.35) & 0.67 (0.34) & 0.63 (0.32) & 0.60 (0.32) }
# v2_swipe_stat_vel_mean
# {0.65 (0.31) & 0.67 (0.32) & 0.66 (0.31) & 0.63 (0.30) & 0.60 (0.29) & 0.58 (0.28) }
# {0.61 (0.29) & 0.62 (0.29) & 0.62 (0.29) & 0.61 (0.29) & 0.59 (0.29) & 0.58 (0.29) }
# {0.47 (0.31) & 0.48 (0.32) & 0.47 (0.32) & 0.47 (0.31) & 0.46 (0.31) & 0.45 (0.31) }
# {0.60 (0.34) & 0.61 (0.35) & 0.60 (0.34) & 0.59 (0.33) & 0.57 (0.32) & 0.55 (0.31) }
# v2_swipe_stat_vel_rms
# {0.67 (0.31) & 0.70 (0.32) & 0.69 (0.31) & 0.66 (0.30) & 0.63 (0.30) & 0.60 (0.29) }
# {0.56 (0.29) & 0.57 (0.29) & 0.57 (0.29) & 0.56 (0.29) & 0.55 (0.29) & 0.54 (0.29) }
# {0.50 (0.33) & 0.51 (0.33) & 0.51 (0.33) & 0.50 (0.32) & 0.49 (0.31) & 0.48 (0.31) }
# {0.58 (0.39) & 0.59 (0.40) & 0.59 (0.39) & 0.57 (0.39) & 0.56 (0.38) & 0.54 (0.37) }
# v2_swipe_stat_vel_both
# {0.66 (0.29) & 0.68 (0.30) & 0.67 (0.29) & 0.65 (0.28) & 0.63 (0.27) & 0.60 (0.27) }
# {0.59 (0.31) & 0.60 (0.31) & 0.60 (0.31) & 0.59 (0.31) & 0.58 (0.31) & 0.56 (0.31) }
# {0.46 (0.31) & 0.47 (0.31) & 0.46 (0.31) & 0.45 (0.31) & 0.44 (0.30) & 0.43 (0.30) }
# {0.53 (0.37) & 0.55 (0.39) & 0.54 (0.38) & 0.52 (0.36) & 0.50 (0.35) & 0.48 (0.33) }
# v2_swipe_stat_acc_mean
# {0.62 (0.34) & 0.63 (0.34) & 0.62 (0.34) & 0.60 (0.34) & 0.58 (0.34) & 0.56 (0.34) }
# {0.44 (0.32) & 0.45 (0.32) & 0.44 (0.32) & 0.43 (0.32) & 0.41 (0.31) & 0.40 (0.31) }
# {0.45 (0.32) & 0.46 (0.32) & 0.45 (0.32) & 0.44 (0.32) & 0.43 (0.32) & 0.42 (0.32) }
# {0.66 (0.37) & 0.69 (0.38) & 0.67 (0.38) & 0.65 (0.36) & 0.62 (0.35) & 0.59 (0.34) }
# v2_swipe_stat_acc_rms
# {0.68 (0.31) & 0.72 (0.33) & 0.70 (0.32) & 0.65 (0.30) & 0.61 (0.29) & 0.57 (0.28) }
# {0.48 (0.32) & 0.48 (0.32) & 0.48 (0.32) & 0.48 (0.32) & 0.47 (0.32) & 0.47 (0.32) }
# {0.60 (0.32) & 0.62 (0.32) & 0.61 (0.32) & 0.60 (0.31) & 0.58 (0.31) & 0.56 (0.30) }
# {0.68 (0.33) & 0.71 (0.34) & 0.69 (0.34) & 0.66 (0.32) & 0.63 (0.32) & 0.59 (0.31) }
# v2_swipe_stat_acc_both
# {0.62 (0.34) & 0.65 (0.36) & 0.63 (0.35) & 0.60 (0.33) & 0.57 (0.32) & 0.54 (0.32) }
# {0.53 (0.31) & 0.54 (0.31) & 0.54 (0.31) & 0.53 (0.31) & 0.51 (0.30) & 0.50 (0.30) }
# {0.45 (0.34) & 0.46 (0.34) & 0.45 (0.34) & 0.45 (0.33) & 0.44 (0.33) & 0.43 (0.33) }
# {0.69 (0.32) & 0.73 (0.34) & 0.71 (0.33) & 0.66 (0.31) & 0.62 (0.29) & 0.58 (0.28) }

# %%
file_names =["swipe_fusion"]
file_names =[f"v2_{el}" for el in file_names]

for name in file_names:
    print(name)
    plot(name)
    print()
# Out:
# v2_swipe_fusion
# {0.54 (0.36) & 0.56 (0.38) & 0.55 (0.37) & 0.52 (0.35) & 0.49 (0.33) & 0.47 (0.32) }
# {0.43 (0.38) & 0.44 (0.38) & 0.44 (0.38) & 0.43 (0.38) & 0.43 (0.38) & 0.42 (0.37) }
# {0.32 (0.26) & 0.32 (0.26) & 0.32 (0.26) & 0.31 (0.26) & 0.31 (0.26) & 0.30 (0.26) }
# {0.45 (0.38) & 0.47 (0.40) & 0.46 (0.39) & 0.44 (0.37) & 0.42 (0.35) & 0.40 (0.34) }
