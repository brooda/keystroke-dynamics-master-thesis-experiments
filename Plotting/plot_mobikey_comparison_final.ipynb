# %%
from plot import plot

# %%
file_names =["mobikey_final", "mobile_final"]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_mobikey_final
# {0.54 (0.38) & 0.59 (0.42) & 0.56 (0.40) & 0.51 (0.36) & 0.45 (0.34) & 0.40 (0.32) }
# {0.42 (0.40) & 0.43 (0.41) & 0.42 (0.40) & 0.41 (0.40) & 0.39 (0.39) & 0.38 (0.39) }
# {0.23 (0.34) & 0.23 (0.35) & 0.23 (0.34) & 0.23 (0.34) & 0.23 (0.34) & 0.23 (0.34) }
# {0.47 (0.42) & 0.50 (0.44) & 0.48 (0.43) & 0.45 (0.41) & 0.42 (0.39) & 0.39 (0.38) }
# v2_mobile_final
# {0.72 (0.40) & 0.74 (0.41) & 0.73 (0.40) & 0.70 (0.39) & 0.68 (0.39) & 0.66 (0.39) }
# {0.53 (0.44) & 0.54 (0.44) & 0.54 (0.44) & 0.53 (0.44) & 0.53 (0.45) & 0.52 (0.45) }
# {0.56 (0.39) & 0.56 (0.39) & 0.56 (0.39) & 0.56 (0.39) & 0.56 (0.39) & 0.56 (0.39) }
# {0.52 (0.45) & 0.53 (0.45) & 0.53 (0.45) & 0.52 (0.44) & 0.51 (0.43) & 0.50 (0.43) }
