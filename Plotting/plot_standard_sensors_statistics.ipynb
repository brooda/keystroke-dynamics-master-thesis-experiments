# %%
from plot import plot

# %%
file_names =["standard_accx_mean", "standard_accx_rms", "standard_accx_both",\
    "standard_accy_mean", "standard_accy_rms", "standard_accy_both",\
    "standard_accz_mean", "standard_accz_rms", "standard_accz_both",\
    "standard_rotx_mean", "standard_rotx_rms", "standard_rotx_both",\
    "standard_roty_mean", "standard_roty_rms", "standard_roty_both",\
    "standard_rotz_mean", "standard_rotz_rms", "standard_rotz_both"\
]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_standard_accx_mean
# {0.89 (0.26) & 0.89 (0.26) & 0.89 (0.26) & 0.89 (0.26) & 0.88 (0.27) & 0.88 (0.27) }
# {0.85 (0.30) & 0.85 (0.29) & 0.85 (0.29) & 0.84 (0.30) & 0.84 (0.30) & 0.84 (0.30) }
# {0.83 (0.31) & 0.84 (0.31) & 0.84 (0.31) & 0.83 (0.31) & 0.83 (0.31) & 0.82 (0.31) }
# {0.83 (0.33) & 0.84 (0.33) & 0.83 (0.33) & 0.82 (0.33) & 0.80 (0.33) & 0.79 (0.34) }
# v2_standard_accx_rms
# {0.91 (0.20) & 0.92 (0.20) & 0.91 (0.20) & 0.91 (0.20) & 0.90 (0.21) & 0.90 (0.21) }
# {0.94 (0.15) & 0.94 (0.15) & 0.94 (0.15) & 0.94 (0.15) & 0.94 (0.15) & 0.94 (0.15) }
# {0.86 (0.25) & 0.86 (0.25) & 0.86 (0.25) & 0.86 (0.25) & 0.86 (0.25) & 0.85 (0.25) }
# {0.87 (0.25) & 0.88 (0.25) & 0.87 (0.25) & 0.87 (0.25) & 0.86 (0.26) & 0.86 (0.26) }
# v2_standard_accx_both
# {0.84 (0.30) & 0.85 (0.29) & 0.84 (0.29) & 0.83 (0.30) & 0.82 (0.31) & 0.81 (0.31) }
# {0.86 (0.27) & 0.87 (0.27) & 0.86 (0.27) & 0.86 (0.28) & 0.85 (0.28) & 0.85 (0.28) }
# {0.81 (0.30) & 0.82 (0.30) & 0.81 (0.30) & 0.81 (0.30) & 0.80 (0.31) & 0.79 (0.31) }
# {0.81 (0.34) & 0.82 (0.35) & 0.82 (0.34) & 0.81 (0.34) & 0.80 (0.35) & 0.79 (0.35) }
# v2_standard_accy_mean
# {0.86 (0.29) & 0.86 (0.28) & 0.86 (0.29) & 0.85 (0.29) & 0.85 (0.29) & 0.85 (0.29) }
# {0.81 (0.31) & 0.82 (0.31) & 0.82 (0.31) & 0.81 (0.31) & 0.81 (0.31) & 0.81 (0.31) }
# {0.88 (0.25) & 0.89 (0.24) & 0.88 (0.24) & 0.87 (0.25) & 0.86 (0.27) & 0.85 (0.28) }
# {0.65 (0.41) & 0.66 (0.40) & 0.65 (0.40) & 0.65 (0.41) & 0.65 (0.41) & 0.64 (0.41) }
# v2_standard_accy_rms
# {0.86 (0.28) & 0.86 (0.28) & 0.86 (0.28) & 0.85 (0.28) & 0.85 (0.29) & 0.85 (0.29) }
# {0.82 (0.31) & 0.82 (0.31) & 0.82 (0.31) & 0.82 (0.32) & 0.81 (0.32) & 0.81 (0.32) }
# {0.87 (0.25) & 0.88 (0.24) & 0.88 (0.25) & 0.87 (0.25) & 0.86 (0.27) & 0.84 (0.28) }
# {0.63 (0.41) & 0.63 (0.40) & 0.63 (0.40) & 0.63 (0.41) & 0.62 (0.41) & 0.62 (0.41) }
# v2_standard_accy_both
# {0.85 (0.29) & 0.86 (0.28) & 0.86 (0.29) & 0.85 (0.29) & 0.85 (0.29) & 0.84 (0.29) }
# {0.84 (0.32) & 0.84 (0.32) & 0.84 (0.32) & 0.83 (0.32) & 0.83 (0.32) & 0.83 (0.33) }
# {0.88 (0.25) & 0.88 (0.24) & 0.88 (0.24) & 0.87 (0.25) & 0.87 (0.25) & 0.86 (0.26) }
# {0.69 (0.36) & 0.70 (0.37) & 0.69 (0.36) & 0.68 (0.37) & 0.66 (0.37) & 0.65 (0.37) }
# v2_standard_accz_mean
# {0.84 (0.27) & 0.85 (0.27) & 0.85 (0.27) & 0.84 (0.27) & 0.83 (0.27) & 0.82 (0.27) }
# {0.87 (0.31) & 0.87 (0.31) & 0.87 (0.31) & 0.86 (0.31) & 0.86 (0.31) & 0.86 (0.31) }
# {0.76 (0.39) & 0.76 (0.39) & 0.76 (0.39) & 0.76 (0.39) & 0.76 (0.39) & 0.76 (0.39) }
# {0.58 (0.41) & 0.59 (0.41) & 0.58 (0.41) & 0.58 (0.41) & 0.57 (0.41) & 0.56 (0.41) }
# v2_standard_accz_rms
# {0.82 (0.30) & 0.83 (0.30) & 0.82 (0.30) & 0.82 (0.31) & 0.81 (0.31) & 0.80 (0.31) }
# {0.86 (0.31) & 0.87 (0.31) & 0.86 (0.31) & 0.86 (0.31) & 0.86 (0.31) & 0.86 (0.31) }
# {0.79 (0.32) & 0.80 (0.32) & 0.79 (0.32) & 0.79 (0.32) & 0.78 (0.33) & 0.78 (0.33) }
# {0.59 (0.42) & 0.59 (0.42) & 0.59 (0.42) & 0.58 (0.42) & 0.58 (0.43) & 0.57 (0.43) }
# v2_standard_accz_both
# {0.85 (0.26) & 0.86 (0.26) & 0.85 (0.26) & 0.85 (0.26) & 0.84 (0.26) & 0.83 (0.27) }
# {0.87 (0.28) & 0.87 (0.28) & 0.87 (0.28) & 0.87 (0.28) & 0.87 (0.28) & 0.86 (0.28) }
# {0.86 (0.30) & 0.87 (0.30) & 0.87 (0.30) & 0.86 (0.30) & 0.86 (0.30) & 0.86 (0.30) }
# {0.56 (0.41) & 0.56 (0.41) & 0.56 (0.41) & 0.55 (0.41) & 0.55 (0.41) & 0.55 (0.41) }
# v2_standard_rotx_mean
# {0.72 (0.31) & 0.73 (0.31) & 0.73 (0.31) & 0.71 (0.31) & 0.70 (0.31) & 0.68 (0.32) }
# {0.55 (0.34) & 0.56 (0.34) & 0.55 (0.34) & 0.55 (0.34) & 0.54 (0.34) & 0.53 (0.34) }
# {0.52 (0.31) & 0.52 (0.31) & 0.52 (0.31) & 0.51 (0.31) & 0.51 (0.30) & 0.50 (0.30) }
# {0.62 (0.39) & 0.64 (0.40) & 0.63 (0.39) & 0.61 (0.38) & 0.60 (0.38) & 0.58 (0.37) }
# v2_standard_rotx_rms
# {0.76 (0.31) & 0.78 (0.32) & 0.77 (0.31) & 0.75 (0.31) & 0.73 (0.31) & 0.71 (0.31) }
# {0.62 (0.35) & 0.63 (0.35) & 0.63 (0.35) & 0.62 (0.35) & 0.61 (0.36) & 0.59 (0.36) }
# {0.60 (0.34) & 0.60 (0.34) & 0.60 (0.34) & 0.59 (0.34) & 0.58 (0.34) & 0.58 (0.34) }
# {0.70 (0.33) & 0.71 (0.34) & 0.71 (0.34) & 0.69 (0.33) & 0.67 (0.32) & 0.66 (0.32) }
# v2_standard_rotx_both
# {0.70 (0.31) & 0.73 (0.31) & 0.71 (0.31) & 0.68 (0.30) & 0.65 (0.30) & 0.62 (0.30) }
# {0.57 (0.36) & 0.57 (0.36) & 0.57 (0.36) & 0.56 (0.36) & 0.55 (0.36) & 0.54 (0.36) }
# {0.41 (0.33) & 0.41 (0.33) & 0.41 (0.33) & 0.40 (0.32) & 0.40 (0.32) & 0.39 (0.32) }
# {0.63 (0.35) & 0.65 (0.36) & 0.64 (0.35) & 0.62 (0.34) & 0.60 (0.33) & 0.58 (0.32) }
# v2_standard_roty_mean
# {0.62 (0.36) & 0.65 (0.37) & 0.63 (0.36) & 0.60 (0.35) & 0.57 (0.34) & 0.54 (0.33) }
# {0.39 (0.34) & 0.40 (0.35) & 0.40 (0.34) & 0.39 (0.34) & 0.38 (0.33) & 0.36 (0.33) }
# {0.46 (0.37) & 0.47 (0.38) & 0.47 (0.38) & 0.46 (0.37) & 0.45 (0.36) & 0.44 (0.36) }
# {0.59 (0.40) & 0.61 (0.42) & 0.60 (0.41) & 0.58 (0.40) & 0.55 (0.38) & 0.53 (0.37) }
# v2_standard_roty_rms
# {0.75 (0.28) & 0.77 (0.29) & 0.76 (0.29) & 0.73 (0.28) & 0.71 (0.28) & 0.68 (0.27) }
# {0.58 (0.40) & 0.59 (0.40) & 0.59 (0.40) & 0.58 (0.39) & 0.57 (0.39) & 0.56 (0.39) }
# {0.44 (0.37) & 0.44 (0.38) & 0.44 (0.38) & 0.43 (0.37) & 0.42 (0.36) & 0.41 (0.36) }
# {0.54 (0.38) & 0.57 (0.40) & 0.55 (0.39) & 0.53 (0.37) & 0.50 (0.36) & 0.47 (0.34) }
# v2_standard_roty_both
# {0.68 (0.36) & 0.71 (0.37) & 0.69 (0.36) & 0.66 (0.35) & 0.62 (0.34) & 0.58 (0.33) }
# {0.44 (0.37) & 0.45 (0.37) & 0.44 (0.37) & 0.43 (0.37) & 0.42 (0.36) & 0.41 (0.36) }
# {0.39 (0.40) & 0.39 (0.40) & 0.39 (0.40) & 0.39 (0.40) & 0.39 (0.40) & 0.39 (0.40) }
# {0.48 (0.39) & 0.50 (0.40) & 0.49 (0.40) & 0.47 (0.38) & 0.45 (0.37) & 0.43 (0.35) }
# v2_standard_rotz_mean
# {0.67 (0.35) & 0.69 (0.36) & 0.68 (0.35) & 0.65 (0.34) & 0.62 (0.33) & 0.60 (0.33) }
# {0.52 (0.35) & 0.53 (0.35) & 0.52 (0.35) & 0.51 (0.35) & 0.50 (0.35) & 0.49 (0.35) }
# {0.49 (0.38) & 0.50 (0.38) & 0.49 (0.38) & 0.49 (0.38) & 0.48 (0.37) & 0.48 (0.37) }
# {0.64 (0.31) & 0.66 (0.32) & 0.65 (0.32) & 0.63 (0.31) & 0.61 (0.30) & 0.59 (0.29) }
# v2_standard_rotz_rms
# {0.69 (0.33) & 0.71 (0.33) & 0.70 (0.33) & 0.68 (0.32) & 0.66 (0.32) & 0.64 (0.31) }
# {0.62 (0.30) & 0.63 (0.30) & 0.62 (0.30) & 0.61 (0.29) & 0.59 (0.29) & 0.58 (0.29) }
# {0.60 (0.29) & 0.61 (0.30) & 0.60 (0.29) & 0.59 (0.29) & 0.58 (0.29) & 0.57 (0.28) }
# {0.60 (0.37) & 0.62 (0.38) & 0.61 (0.38) & 0.59 (0.37) & 0.58 (0.36) & 0.56 (0.36) }
# v2_standard_rotz_both
# {0.72 (0.37) & 0.75 (0.38) & 0.73 (0.38) & 0.70 (0.37) & 0.66 (0.36) & 0.63 (0.36) }
# {0.37 (0.31) & 0.38 (0.31) & 0.37 (0.31) & 0.37 (0.30) & 0.36 (0.30) & 0.35 (0.30) }
# {0.46 (0.33) & 0.46 (0.33) & 0.46 (0.33) & 0.45 (0.33) & 0.45 (0.33) & 0.44 (0.33) }
# {0.56 (0.34) & 0.58 (0.36) & 0.57 (0.34) & 0.54 (0.33) & 0.52 (0.31) & 0.50 (0.30) }
