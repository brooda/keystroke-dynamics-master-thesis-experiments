# %%
from plot import plot

# %%
file_names =["swipe_pos_correct", "swipe_pos_frag_correct", "swipe_vel_correct", \
             "swipe_vel_frag_correct", "swipe_acc_correct", "swipe_acc_frag_correct"]

file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    print()
# Out:
# v2_swipe_pos_correct
# {0.77 (0.20) & 0.78 (0.20) & 0.77 (0.20) & 0.76 (0.20) & 0.74 (0.20) & 0.73 (0.20) }
# {0.85 (0.13) & 0.86 (0.13) & 0.85 (0.13) & 0.84 (0.13) & 0.82 (0.13) & 0.81 (0.14) }
# {0.75 (0.19) & 0.76 (0.19) & 0.76 (0.19) & 0.75 (0.19) & 0.74 (0.19) & 0.73 (0.20) }
# {0.83 (0.19) & 0.84 (0.20) & 0.84 (0.19) & 0.82 (0.19) & 0.80 (0.18) & 0.79 (0.18) }
# v2_swipe_pos_frag_correct
# {0.76 (0.27) & 0.77 (0.28) & 0.77 (0.27) & 0.75 (0.27) & 0.73 (0.26) & 0.71 (0.25) }
# {0.64 (0.25) & 0.65 (0.26) & 0.64 (0.25) & 0.63 (0.25) & 0.61 (0.25) & 0.60 (0.24) }
# {0.72 (0.23) & 0.74 (0.23) & 0.73 (0.23) & 0.72 (0.23) & 0.70 (0.22) & 0.69 (0.23) }
# {0.82 (0.24) & 0.86 (0.25) & 0.84 (0.24) & 0.79 (0.23) & 0.74 (0.22) & 0.69 (0.22) }
# v2_swipe_vel_correct
# {0.80 (0.21) & 0.81 (0.22) & 0.80 (0.21) & 0.79 (0.21) & 0.77 (0.21) & 0.75 (0.21) }
# {0.70 (0.18) & 0.71 (0.18) & 0.71 (0.18) & 0.69 (0.18) & 0.68 (0.17) & 0.67 (0.17) }
# ...
