# %%
from plot import plot

# %%
file_names =["swipe_accx_signal", "swipe_accx_signalpieces", \
    "swipe_accy_signal", "swipe_accy_signalpieces", \
    "swipe_accz_signal", "swipe_accz_signalpieces", \
    "swipe_rotx_signal", "swipe_rotx_signalpieces", \
    "swipe_roty_signal", "swipe_roty_signalpieces", \
    "swipe_rotz_signal", "swipe_rotz_signalpieces" ]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_swipe_accx_signal
# {0.85 (0.21) & 0.86 (0.21) & 0.86 (0.21) & 0.85 (0.21) & 0.83 (0.21) & 0.82 (0.21) }
# {0.89 (0.14) & 0.89 (0.14) & 0.89 (0.14) & 0.89 (0.14) & 0.88 (0.15) & 0.88 (0.15) }
# {0.90 (0.18) & 0.90 (0.18) & 0.90 (0.18) & 0.89 (0.19) & 0.88 (0.19) & 0.87 (0.19) }
# {0.88 (0.23) & 0.89 (0.23) & 0.88 (0.23) & 0.87 (0.24) & 0.86 (0.24) & 0.85 (0.24) }
# v2_swipe_accx_signalpieces
# {0.90 (0.18) & 0.91 (0.18) & 0.90 (0.18) & 0.90 (0.18) & 0.89 (0.18) & 0.88 (0.18) }
# {0.92 (0.17) & 0.92 (0.17) & 0.92 (0.17) & 0.91 (0.17) & 0.91 (0.17) & 0.91 (0.17) }
# {0.82 (0.22) & 0.83 (0.21) & 0.83 (0.21) & 0.82 (0.22) & 0.82 (0.22) & 0.81 (0.22) }
# {0.88 (0.25) & 0.89 (0.25) & 0.88 (0.25) & 0.87 (0.25) & 0.86 (0.24) & 0.85 (0.24) }
# v2_swipe_accy_signal
# {0.86 (0.19) & 0.87 (0.19) & 0.86 (0.19) & 0.85 (0.19) & 0.83 (0.19) & 0.82 (0.20) }
# {0.90 (0.15) & 0.91 (0.15) & 0.91 (0.15) & 0.90 (0.15) & 0.89 (0.15) & 0.88 (0.16) }
# {0.88 (0.21) & 0.89 (0.21) & 0.88 (0.21) & 0.87 (0.21) & 0.86 (0.22) & 0.85 (0.22) }
# {0.94 (0.14) & 0.95 (0.14) & 0.95 (0.14) & 0.93 (0.14) & 0.92 (0.14) & 0.91 (0.15) }
# v2_swipe_accy_signalpieces
# {0.88 (0.17) & 0.89 (0.17) & 0.88 (0.17) & 0.87 (0.17) & 0.85 (0.18) & 0.83 (0.19) }
# {0.88 (0.20) & 0.89 (0.20) & 0.89 (0.20) & 0.88 (0.20) & 0.87 (0.21) & 0.87 (0.21) }
# {0.85 (0.27) & 0.85 (0.27) & 0.85 (0.27) & 0.84 (0.27) & 0.84 (0.27) & 0.83 (0.27) }
# {0.95 (0.12) & 0.96 (0.12) & 0.95 (0.12) & 0.94 (0.12) & 0.93 (0.12) & 0.91 (0.12) }
# v2_swipe_accz_signal
# {0.90 (0.21) & 0.91 (0.21) & 0.90 (0.21) & 0.89 (0.21) & 0.89 (0.20) & 0.88 (0.20) }
# {0.89 (0.21) & 0.89 (0.21) & 0.89 (0.21) & 0.88 (0.21) & 0.88 (0.22) & 0.87 (0.22) }
# {0.95 (0.14) & 0.95 (0.13) & 0.95 (0.13) & 0.94 (0.14) & 0.94 (0.15) & 0.93 (0.16) }
# {0.93 (0.14) & 0.94 (0.14) & 0.94 (0.14) & 0.93 (0.15) & 0.91 (0.15) & 0.90 (0.16) }
# v2_swipe_accz_signalpieces
# {0.88 (0.21) & 0.90 (0.21) & 0.89 (0.21) & 0.87 (0.21) & 0.84 (0.22) & 0.82 (0.23) }
# {0.88 (0.21) & 0.88 (0.21) & 0.88 (0.21) & 0.87 (0.22) & 0.86 (0.22) & 0.86 (0.23) }
# {0.83 (0.28) & 0.83 (0.28) & 0.83 (0.28) & 0.82 (0.28) & 0.82 (0.28) & 0.82 (0.28) }
# {0.93 (0.14) & 0.94 (0.14) & 0.93 (0.14) & 0.92 (0.14) & 0.91 (0.14) & 0.89 (0.15) }
# v2_swipe_rotx_signal
# {0.85 (0.20) & 0.87 (0.20) & 0.86 (0.20) & 0.84 (0.20) & 0.83 (0.20) & 0.81 (0.20) }
# {0.75 (0.22) & 0.76 (0.22) & 0.75 (0.22) & 0.74 (0.22) & 0.74 (0.23) & 0.73 (0.23) }
# {0.80 (0.26) & 0.81 (0.26) & 0.81 (0.26) & 0.80 (0.26) & 0.79 (0.26) & 0.79 (0.26) }
# {0.87 (0.19) & 0.88 (0.19) & 0.88 (0.19) & 0.86 (0.19) & 0.84 (0.19) & 0.82 (0.20) }
# v2_swipe_rotx_signalpieces
# {0.76 (0.26) & 0.77 (0.26) & 0.77 (0.26) & 0.75 (0.27) & 0.74 (0.27) & 0.73 (0.28) }
# {0.70 (0.28) & 0.70 (0.28) & 0.70 (0.28) & 0.69 (0.28) & 0.69 (0.28) & 0.68 (0.28) }
# {0.73 (0.29) & 0.74 (0.30) & 0.73 (0.30) & 0.72 (0.29) & 0.71 (0.29) & 0.70 (0.29) }
# {0.79 (0.28) & 0.81 (0.29) & 0.80 (0.28) & 0.77 (0.28) & 0.75 (0.27) & 0.72 (0.27) }
# v2_swipe_roty_signal
# {0.82 (0.22) & 0.83 (0.23) & 0.82 (0.22) & 0.81 (0.22) & 0.79 (0.22) & 0.77 (0.22) }
# {0.84 (0.20) & 0.85 (0.20) & 0.85 (0.20) & 0.84 (0.20) & 0.83 (0.20) & 0.82 (0.20) }
# {0.87 (0.22) & 0.88 (0.22) & 0.87 (0.22) & 0.86 (0.22) & 0.84 (0.23) & 0.83 (0.23) }
# {0.82 (0.23) & 0.84 (0.24) & 0.83 (0.23) & 0.81 (0.23) & 0.80 (0.23) & 0.78 (0.23) }
# v2_swipe_roty_signalpieces
# {0.74 (0.37) & 0.76 (0.38) & 0.75 (0.37) & 0.72 (0.36) & 0.70 (0.35) & 0.67 (0.34) }
# {0.61 (0.30) & 0.62 (0.30) & 0.61 (0.30) & 0.61 (0.30) & 0.60 (0.30) & 0.60 (0.30) }
# {0.53 (0.32) & 0.54 (0.33) & 0.54 (0.32) & 0.53 (0.32) & 0.52 (0.31) & 0.51 (0.31) }
# {0.74 (0.35) & 0.76 (0.36) & 0.75 (0.35) & 0.72 (0.34) & 0.70 (0.33) & 0.68 (0.32) }
# v2_swipe_rotz_signal
# {0.83 (0.25) & 0.85 (0.25) & 0.84 (0.25) & 0.82 (0.25) & 0.81 (0.25) & 0.79 (0.25) }
# {0.77 (0.21) & 0.78 (0.21) & 0.77 (0.21) & 0.77 (0.21) & 0.76 (0.21) & 0.75 (0.21) }
# {0.82 (0.26) & 0.82 (0.26) & 0.82 (0.26) & 0.81 (0.26) & 0.80 (0.26) & 0.79 (0.26) }
# {0.86 (0.21) & 0.87 (0.21) & 0.86 (0.21) & 0.86 (0.21) & 0.85 (0.21) & 0.85 (0.20) }
# v2_swipe_rotz_signalpieces
# {0.77 (0.23) & 0.78 (0.24) & 0.78 (0.23) & 0.76 (0.23) & 0.75 (0.23) & 0.74 (0.23) }
# {0.71 (0.26) & 0.72 (0.26) & 0.71 (0.26) & 0.70 (0.26) & 0.69 (0.26) & 0.68 (0.26) }
# {0.69 (0.29) & 0.69 (0.29) & 0.69 (0.29) & 0.68 (0.29) & 0.68 (0.28) & 0.67 (0.28) }
# {0.82 (0.26) & 0.85 (0.27) & 0.84 (0.27) & 0.81 (0.26) & 0.77 (0.26) & 0.74 (0.26) }
