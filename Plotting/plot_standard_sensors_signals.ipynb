# %%
from plot import plot

# %%
file_names =["standard_accx_signal",
    "standard_accx_signalpieces", \
    "standard_accy_signal", "standard_accy_signalpieces", \
    "standard_accz_signal", "standard_accz_signalpieces", \
    "standard_rotx_signal", "standard_rotx_signalpieces", \
    "standard_roty_signal", "standard_roty_signalpieces", \
    "standard_rotz_signal", "standard_rotz_signalpieces" ]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_standard_accx_signal
# {0.95 (0.09) & 0.96 (0.09) & 0.95 (0.09) & 0.95 (0.09) & 0.94 (0.09) & 0.93 (0.10) }
# {0.92 (0.09) & 0.93 (0.09) & 0.92 (0.09) & 0.91 (0.10) & 0.90 (0.11) & 0.89 (0.11) }
# {0.96 (0.11) & 0.96 (0.11) & 0.96 (0.11) & 0.96 (0.11) & 0.95 (0.11) & 0.94 (0.12) }
# {0.90 (0.17) & 0.91 (0.17) & 0.90 (0.17) & 0.89 (0.17) & 0.89 (0.17) & 0.88 (0.18) }
# v2_standard_accx_signalpieces
# {0.90 (0.18) & 0.92 (0.19) & 0.91 (0.18) & 0.89 (0.19) & 0.87 (0.19) & 0.85 (0.20) }
# {0.91 (0.16) & 0.92 (0.16) & 0.91 (0.16) & 0.91 (0.16) & 0.90 (0.16) & 0.90 (0.16) }
# {0.82 (0.21) & 0.83 (0.21) & 0.82 (0.21) & 0.82 (0.21) & 0.82 (0.21) & 0.81 (0.22) }
# {0.92 (0.15) & 0.94 (0.14) & 0.93 (0.15) & 0.91 (0.15) & 0.88 (0.17) & 0.86 (0.19) }
# v2_standard_accy_signal
# {0.82 (0.26) & 0.83 (0.26) & 0.82 (0.26) & 0.82 (0.26) & 0.82 (0.26) & 0.81 (0.26) }
# {0.88 (0.21) & 0.88 (0.21) & 0.88 (0.21) & 0.88 (0.21) & 0.87 (0.21) & 0.87 (0.21) }
# {0.89 (0.19) & 0.90 (0.20) & 0.89 (0.19) & 0.89 (0.19) & 0.88 (0.19) & 0.88 (0.19) }
# {0.95 (0.10) & 0.96 (0.09) & 0.95 (0.09) & 0.94 (0.10) & 0.93 (0.10) & 0.92 (0.11) }
# v2_standard_accy_signalpieces
# {0.80 (0.31) & 0.80 (0.31) & 0.80 (0.31) & 0.80 (0.31) & 0.79 (0.31) & 0.79 (0.31) }
# {0.81 (0.31) & 0.81 (0.31) & 0.81 (0.31) & 0.80 (0.31) & 0.80 (0.31) & 0.80 (0.31) }
# {0.87 (0.21) & 0.87 (0.21) & 0.87 (0.21) & 0.86 (0.21) & 0.86 (0.21) & 0.86 (0.21) }
# {0.85 (0.25) & 0.86 (0.26) & 0.85 (0.25) & 0.84 (0.25) & 0.82 (0.26) & 0.80 (0.26) }
# v2_standard_accz_signal
# {0.89 (0.18) & 0.90 (0.19) & 0.90 (0.18) & 0.88 (0.18) & 0.86 (0.19) & 0.84 (0.20) }
# {0.89 (0.20) & 0.89 (0.19) & 0.89 (0.19) & 0.89 (0.20) & 0.88 (0.20) & 0.88 (0.21) }
# {0.91 (0.23) & 0.91 (0.23) & 0.91 (0.23) & 0.90 (0.23) & 0.89 (0.23) & 0.88 (0.24) }
# {0.93 (0.14) & 0.94 (0.13) & 0.93 (0.14) & 0.92 (0.14) & 0.91 (0.15) & 0.90 (0.16) }
# v2_standard_accz_signalpieces
# {0.83 (0.26) & 0.84 (0.26) & 0.83 (0.26) & 0.83 (0.26) & 0.82 (0.26) & 0.81 (0.26) }
# {0.86 (0.23) & 0.86 (0.23) & 0.86 (0.23) & 0.85 (0.23) & 0.85 (0.24) & 0.84 (0.24) }
# {0.86 (0.23) & 0.87 (0.23) & 0.86 (0.23) & 0.86 (0.23) & 0.86 (0.23) & 0.86 (0.23) }
# {0.84 (0.26) & 0.85 (0.26) & 0.85 (0.26) & 0.84 (0.26) & 0.82 (0.26) & 0.81 (0.26) }
# v2_standard_rotx_signal
# {0.88 (0.23) & 0.89 (0.23) & 0.88 (0.23) & 0.87 (0.23) & 0.85 (0.23) & 0.84 (0.23) }
# {0.80 (0.23) & 0.81 (0.23) & 0.81 (0.23) & 0.80 (0.23) & 0.79 (0.23) & 0.78 (0.23) }
# {0.81 (0.27) & 0.82 (0.28) & 0.81 (0.27) & 0.81 (0.27) & 0.80 (0.27) & 0.79 (0.27) }
# {0.77 (0.27) & 0.77 (0.27) & 0.77 (0.27) & 0.76 (0.26) & 0.76 (0.26) & 0.75 (0.26) }
# v2_standard_rotx_signalpieces
# {0.70 (0.32) & 0.71 (0.32) & 0.70 (0.32) & 0.69 (0.32) & 0.69 (0.32) & 0.68 (0.32) }
# {0.57 (0.25) & 0.58 (0.25) & 0.57 (0.25) & 0.56 (0.25) & 0.55 (0.25) & 0.54 (0.25) }
# {0.63 (0.28) & 0.64 (0.29) & 0.63 (0.29) & 0.62 (0.28) & 0.61 (0.28) & 0.60 (0.28) }
# {0.75 (0.26) & 0.78 (0.28) & 0.76 (0.27) & 0.72 (0.26) & 0.68 (0.25) & 0.65 (0.25) }
# v2_standard_roty_signal
# {0.76 (0.27) & 0.77 (0.27) & 0.77 (0.27) & 0.75 (0.27) & 0.74 (0.26) & 0.73 (0.27) }
# {0.79 (0.25) & 0.80 (0.25) & 0.79 (0.25) & 0.78 (0.25) & 0.77 (0.25) & 0.77 (0.25) }
# {0.75 (0.26) & 0.76 (0.26) & 0.75 (0.26) & 0.74 (0.26) & 0.73 (0.26) & 0.72 (0.26) }
# {0.89 (0.15) & 0.89 (0.15) & 0.89 (0.15) & 0.88 (0.15) & 0.87 (0.16) & 0.86 (0.16) }
# v2_standard_roty_signalpieces
# {0.59 (0.32) & 0.62 (0.33) & 0.60 (0.32) & 0.58 (0.31) & 0.55 (0.29) & 0.52 (0.28) }
# {0.49 (0.30) & 0.49 (0.30) & 0.49 (0.30) & 0.48 (0.29) & 0.48 (0.29) & 0.47 (0.29) }
# {0.51 (0.28) & 0.52 (0.29) & 0.52 (0.28) & 0.50 (0.28) & 0.49 (0.28) & 0.48 (0.28) }
# {0.68 (0.35) & 0.70 (0.37) & 0.69 (0.36) & 0.66 (0.34) & 0.64 (0.33) & 0.61 (0.32) }
# v2_standard_rotz_signal
# {0.82 (0.23) & 0.83 (0.23) & 0.82 (0.23) & 0.81 (0.23) & 0.80 (0.23) & 0.79 (0.23) }
# {0.80 (0.23) & 0.81 (0.23) & 0.81 (0.23) & 0.80 (0.23) & 0.78 (0.22) & 0.77 (0.22) }
# {0.80 (0.25) & 0.81 (0.25) & 0.81 (0.25) & 0.80 (0.25) & 0.79 (0.24) & 0.78 (0.24) }
# {0.90 (0.21) & 0.92 (0.21) & 0.91 (0.21) & 0.89 (0.21) & 0.87 (0.21) & 0.86 (0.21) }
# v2_standard_rotz_signalpieces
# {0.64 (0.31) & 0.66 (0.31) & 0.65 (0.31) & 0.63 (0.30) & 0.62 (0.30) & 0.60 (0.29) }
# {0.63 (0.27) & 0.64 (0.27) & 0.64 (0.27) & 0.63 (0.26) & 0.61 (0.26) & 0.60 (0.26) }
# {0.61 (0.24) & 0.62 (0.24) & 0.61 (0.24) & 0.60 (0.24) & 0.59 (0.25) & 0.58 (0.25) }
# {0.79 (0.30) & 0.82 (0.31) & 0.80 (0.31) & 0.77 (0.29) & 0.73 (0.29) & 0.69 (0.28) }
