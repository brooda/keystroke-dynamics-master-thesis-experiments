# %%
from plot import plot

# %%
file_names =[
    "standard_accxyz_mean", "standard_accxyz_rms", "standard_accxyz_both",\
    "standard_rotxyz_mean", "standard_rotxyz_rms", "standard_rotxyz_both",\
    "standard_accxyz_all", "standard_rotxyz_all"
]
file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# v2_standard_accxyz_mean
# {0.81 (0.31) & 0.83 (0.32) & 0.82 (0.31) & 0.80 (0.32) & 0.78 (0.32) & 0.76 (0.34) }
# {0.87 (0.30) & 0.88 (0.30) & 0.87 (0.30) & 0.87 (0.30) & 0.87 (0.30) & 0.86 (0.30) }
# {0.80 (0.36) & 0.80 (0.35) & 0.80 (0.35) & 0.80 (0.36) & 0.80 (0.36) & 0.80 (0.36) }
# {0.73 (0.37) & 0.74 (0.37) & 0.73 (0.37) & 0.72 (0.37) & 0.71 (0.37) & 0.71 (0.37) }
# v2_standard_accxyz_rms
# {0.91 (0.14) & 0.93 (0.13) & 0.92 (0.13) & 0.91 (0.14) & 0.89 (0.16) & 0.88 (0.18) }
# {0.90 (0.26) & 0.90 (0.26) & 0.90 (0.26) & 0.90 (0.26) & 0.90 (0.27) & 0.89 (0.27) }
# {0.84 (0.32) & 0.85 (0.31) & 0.84 (0.32) & 0.84 (0.32) & 0.83 (0.33) & 0.82 (0.33) }
# {0.87 (0.26) & 0.87 (0.26) & 0.87 (0.26) & 0.87 (0.26) & 0.87 (0.27) & 0.87 (0.27) }
# v2_standard_accxyz_both
# {0.84 (0.30) & 0.85 (0.30) & 0.84 (0.30) & 0.84 (0.30) & 0.83 (0.30) & 0.83 (0.30) }
# {0.82 (0.33) & 0.83 (0.32) & 0.82 (0.32) & 0.82 (0.33) & 0.81 (0.33) & 0.81 (0.33) }
# {0.81 (0.33) & 0.81 (0.33) & 0.81 (0.33) & 0.80 (0.34) & 0.80 (0.34) & 0.80 (0.34) }
# {0.77 (0.38) & 0.78 (0.39) & 0.77 (0.38) & 0.77 (0.39) & 0.76 (0.39) & 0.75 (0.39) }
# v2_standard_rotxyz_mean
# {0.64 (0.31) & 0.67 (0.32) & 0.65 (0.31) & 0.62 (0.30) & 0.58 (0.29) & 0.55 (0.29) }
# {0.29 (0.30) & 0.30 (0.31) & 0.29 (0.30) & 0.28 (0.29) & 0.26 (0.28) & 0.25 (0.26) }
# {0.25 (0.29) & 0.26 (0.30) & 0.25 (0.29) & 0.25 (0.28) & 0.24 (0.27) & 0.23 (0.27) }
# {0.50 (0.38) & 0.53 (0.41) & 0.51 (0.39) & 0.48 (0.36) & 0.44 (0.34) & 0.41 (0.33) }
# v2_standard_rotxyz_rms
# {0.56 (0.38) & 0.58 (0.39) & 0.57 (0.39) & 0.55 (0.38) & 0.52 (0.37) & 0.50 (0.36) }
# {0.48 (0.41) & 0.48 (0.41) & 0.48 (0.41) & 0.47 (0.40) & 0.46 (0.40) & 0.45 (0.40) }
# {0.40 (0.40) & 0.40 (0.41) & 0.40 (0.41) & 0.40 (0.40) & 0.40 (0.40) & 0.39 (0.40) }
# {0.49 (0.42) & 0.51 (0.43) & 0.50 (0.43) & 0.49 (0.42) & 0.47 (0.41) & 0.46 (0.40) }
# v2_standard_rotxyz_both
# {0.61 (0.36) & 0.66 (0.39) & 0.64 (0.38) & 0.58 (0.35) & 0.53 (0.32) & 0.48 (0.31) }
# {0.39 (0.39) & 0.40 (0.40) & 0.39 (0.39) & 0.38 (0.39) & 0.37 (0.38) & 0.36 (0.38) }
# {0.20 (0.29) & 0.20 (0.29) & 0.20 (0.29) & 0.20 (0.29) & 0.20 (0.29) & 0.20 (0.29) }
# {0.33 (0.37) & 0.34 (0.39) & 0.33 (0.38) & 0.32 (0.36) & 0.30 (0.34) & 0.29 (0.33) }
# v2_standard_accxyz_all
# {0.77 (0.34) & 0.79 (0.33) & 0.78 (0.34) & 0.76 (0.35) & 0.73 (0.36) & 0.71 (0.37) }
# {0.68 (0.39) & 0.69 (0.38) & 0.68 (0.39) & 0.67 (0.39) & 0.66 (0.39) & 0.65 (0.40) }
# {0.71 (0.35) & 0.71 (0.35) & 0.71 (0.35) & 0.70 (0.35) & 0.70 (0.35) & 0.69 (0.35) }
# {0.73 (0.38) & 0.75 (0.39) & 0.74 (0.38) & 0.72 (0.38) & 0.71 (0.38) & 0.69 (0.38) }
# v2_standard_rotxyz_all
# {0.38 (0.38) & 0.42 (0.42) & 0.40 (0.40) & 0.36 (0.35) & 0.31 (0.31) & 0.27 (0.27) }
# {0.29 (0.32) & 0.30 (0.33) & 0.29 (0.32) & 0.28 (0.31) & 0.27 (0.30) & 0.26 (0.29) }
# {0.14 (0.24) & 0.14 (0.24) & 0.14 (0.24) & 0.14 (0.24) & 0.14 (0.24) & 0.13 (0.24) }
# {0.34 (0.40) & 0.35 (0.42) & 0.34 (0.41) & 0.33 (0.38) & 0.31 (0.36) & 0.29 (0.34) }
