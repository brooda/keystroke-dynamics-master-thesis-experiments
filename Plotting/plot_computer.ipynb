# %%
from plot import plot

# %%
file_names =["computer_maxion", "computer_maxion_bigger"]
#file_names =[f"v2_{el}" for el in file_names]

# %%
for name in file_names:
    print(name)
    plot(name)
    
    print()
    print()
# Out:
# computer_maxion
# 0.53 (0.37) & 0.58 (0.40) & 0.55 (0.39) & 0.51 (0.36) & 0.46 (0.33) & 0.42 (0.31)
# 0.22 (0.25) & 0.23 (0.26) & 0.22 (0.26) & 0.21 (0.25) & 0.21 (0.25) & 0.20 (0.24)
# 0.25 (0.26) & 0.25 (0.26) & 0.25 (0.26) & 0.24 (0.26) & 0.24 (0.25) & 0.23 (0.25)
# 0.39 (0.36) & 0.40 (0.38) & 0.39 (0.37) & 0.37 (0.34) & 0.35 (0.32) & 0.33 (0.31)
# computer_maxion_bigger
# 0.35 (0.34) & 0.42 (0.40) & 0.38 (0.37) & 0.31 (0.31) & 0.23 (0.28) & 0.17 (0.26)
# 0.17 (0.21) & 0.19 (0.22) & 0.18 (0.22) & 0.17 (0.21) & 0.16 (0.20) & 0.10 (0.15)
# 0.25 (0.28) & 0.28 (0.32) & 0.27 (0.30) & 0.25 (0.27) & 0.23 (0.25) & 0.11 (0.16)
# 0.40 (0.35) & 0.45 (0.40) & 0.42 (0.37) & 0.37 (0.33) & 0.32 (0.29) & 0.20 (0.25)
